# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import sys

lis = ["bst_double_double_b.txt", "umap_double_double.txt", "bst_double_double_u.txt", "map_double_double.txt", "bst_int_int_b.txt", "map_int_int.txt", "bst_int_int_u.txt", "umap_int_int.txt", "bst_char_char_b.txt", "map_char_char.txt", "bst_char_char_u.txt", "umap_char_char.txt"]

#lis = ["bst_int_int"]
data = np.zeros((50,12))
for i, item in enumerate(lis):
       data[:,i] = np.loadtxt(item)
        #print(item+".txt")

data = np.array(data)
x = np.arange(1, 51)

x = 100000*x

for i, item in enumerate(lis[:4]):
    plt.plot(x, (data[:,i]), label=item)
    
plt.xlabel("pairs(int, int)")
plt.ylabel("seconds")
plt.legend(loc='upper left')
plt.grid()
plt.show()
plt.savefig('int_int.png', dpi=600, bbox_inches='tight', pad_inches=0.0)
print("figure saved")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-22470f3de7d0> in <module>()
#       9 data = np.zeros((50,12))
#      10 for i, item in enumerate(lis):
# ---> 11        data[:,i] = np.loadtxt(item)
#      12         #print(item+".txt")
#      13
#
# ~/anaconda3/envs/ammasc/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     966             fname = os_fspath(fname)
#     967         if _is_string_like(fname):
# --> 968             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     969             fencoding = getattr(fh, 'encoding', 'latin1')
#     970             fh = iter(fh)
#
# ~/anaconda3/envs/ammasc/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# ~/anaconda3/envs/ammasc/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: bst_double_double_b.txt not found.

# %%
for i, item in enumerate(lis[4:8]):
    plt.plot(x, (data[:,i+4]), label=item)
    
plt.xlabel("pairs(int, int)")
plt.ylabel("seconds")
plt.legend(loc='upper left')
plt.grid()
plt.show()
plt.savefig('double_double.png', dpi=600, bbox_inches='tight', pad_inches=0.0)
print("figure saved")
# Out:
# figure saved

# %%
for i, item in enumerate(lis[8:12]):
    plt.plot(x, (data[:,i+8]), label=item)
    
plt.xlabel("pairs(int, int)")
plt.ylabel("seconds")
plt.legend(loc='upper left')
plt.grid()
plt.show()
plt.savefig('bau_bau.png', dpi=600, bbox_inches='tight', pad_inches=0.0)
print("figure saved")
# Out:
# figure saved

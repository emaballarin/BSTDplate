# %%
import numpy as np
import matplotlib.pyplot as plt
import copy
import sys

#lis = ["bst_int_int","map_int_int","umap_int_int",
#       "bst_double_double","map_double_double","umap_double_double",
#       "bst_char_char","map_char_char","umap_char_char"]

lis = ["bst_int_int","map_int_int","umap_int_int",
       "bst_double_double","map_double_double","umap_double_double",
       "bst_char_char","map_char_char","umap_char_char"]
data = np.zeros((999,2))
for i, item in enumerate(lis):
       data[:,i] = np.loadtxt(item+".txt")
        #print(item+".txt")
# Out:
#   File "<ipython-input-11-d10c803e34d5>", line 11
#     for i, item in enumerate(lis) if i<2:
#                                         ^
# SyntaxError: invalid syntax

# %%
data = np.array(data)
x = np.arange(1, 100)

# %%
plt.plot(x, np.log(data[:,0]))
plt.show()

# %%
plt.plot(x, np.log(data[:,3:6]))
plt.show()

# %%
plt.plot(x, np.log(data[:,6:]))
plt.show()

# %%
#plt.savefig(item+'.svg', dpi=300, bbox_inches='tight', pad_inches=0.0)
#print("figure saved")
